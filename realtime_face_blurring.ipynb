# %% [markdown]
# **importing the required libraries**

# %%
import cv2
import face_recognition

# %% [markdown]
# **capture the video from default camera**

# %%
webcam_video_stream = cv2.VideoCapture(0)

# %% [markdown]
# **initialize the array variable to hold all face locations in the frame**

# %%
all_face_locations = []

# %% [markdown]
# **loop through every frame in the video**

# %%
while True:
    #get the current frame from the video stream as an image
    ret,current_frame = webcam_video_stream.read()
    #resize the current frame to 1/4 size to proces faster
    current_frame_small = cv2.resize(current_frame,(0,0),fx=0.25,fy=0.25)
    #detect all faces in the image
    #arguments are image,no_of_times_to_upsample, model
    all_face_locations = face_recognition.face_locations(current_frame_small,number_of_times_to_upsample=2,model='hog')
    
    #looping through the face locations
    for index,current_face_location in enumerate(all_face_locations):
        #splitting the tuple to get the four position values of current face
        top_pos,right_pos,bottom_pos,left_pos = current_face_location
        #change the position maginitude to fit the actual size video frame
        top_pos = top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        #printing the location of current face
        print('Found face {} at top:{},right:{},bottom:{},left:{}'.format(index+1,top_pos,right_pos,bottom_pos,left_pos))
       
        #Extract the face from the frame, blur it, paste it back to the frame
        #slicing the current face from main image
        current_face_image = current_frame[top_pos:bottom_pos,left_pos:right_pos]
        #blur the sliced face and save it to the same array itself
        current_face_image = cv2.GaussianBlur(current_face_image, (99,99), 30)
        #paste the blurred face into the actual frame
        current_frame[top_pos:bottom_pos,left_pos:right_pos] = current_face_image
        
        
        #draw rectangle around the face detected
        cv2.rectangle(current_frame,(left_pos,top_pos),(right_pos,bottom_pos),(0,0,255),2)
    #showing the current face with rectangle drawn
    cv2.imshow("Webcam Video",current_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

#release the stream and cam
#close all opencv windows open
webcam_video_stream.release()
cv2.destroyAllWindows()
# Out:
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:68,right:464,bottom:248,left:284
# Found face 1 at top:68,right:464,bottom:248,left:284
# Found face 1 at top:68,right:464,bottom:248,left:284
# Found face 1 at top:68,right:464,bottom:248,left:284
# Found face 1 at top:48,right:444,bottom:228,left:264
# Found face 1 at top:48,right:444,bottom:228,left:264
# Found face 1 at top:32,right:424,bottom:208,left:248
# Found face 1 at top:32,right:424,bottom:208,left:248
# Found face 1 at top:32,right:424,bottom:208,left:248
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:32,right:404,bottom:208,left:228
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:32,right:360,bottom:156,left:236
# Found face 1 at top:48,right:360,bottom:172,left:236
# Found face 1 at top:48,right:360,bottom:172,left:236
# Found face 1 at top:40,right:388,bottom:188,left:236
# Found face 1 at top:40,right:388,bottom:188,left:236
# Found face 1 at top:40,right:388,bottom:188,left:236
# Found face 1 at top:56,right:404,bottom:208,left:252
# Found face 1 at top:56,right:404,bottom:208,left:252
# Found face 1 at top:56,right:404,bottom:208,left:252
# Found face 1 at top:56,right:420,bottom:208,left:268
# Found face 1 at top:56,right:420,bottom:208,left:268
# Found face 1 at top:48,right:444,bottom:228,left:264
# Found face 1 at top:48,right:444,bottom:228,left:264
# Found face 1 at top:48,right:444,bottom:228,left:264
# Found face 1 at top:60,right:416,bottom:184,left:292
# Found face 1 at top:60,right:416,bottom:184,left:292
# Found face 1 at top:56,right:436,bottom:208,left:288
# Found face 1 at top:56,right:436,bottom:208,left:288
# Found face 1 at top:32,right:444,bottom:208,left:264
# Found face 1 at top:40,right:420,bottom:188,left:268
# Found face 1 at top:24,right:420,bottom:172,left:268
# Found face 1 at top:24,right:420,bottom:172,left:268
# Found face 1 at top:24,right:420,bottom:172,left:268
# Found face 1 at top:24,right:404,bottom:172,left:252
# Found face 1 at top:24,right:404,bottom:172,left:252
# Found face 1 at top:24,right:404,bottom:172,left:252
# Found face 1 at top:24,right:404,bottom:172,left:252
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:20,right:376,bottom:144,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:24,right:388,bottom:172,left:236
# Found face 1 at top:20,right:376,bottom:144,left:252
# Found face 1 at top:20,right:376,bottom:144,left:252
# Found face 1 at top:20,right:376,bottom:144,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:32,right:376,bottom:156,left:252
# Found face 1 at top:48,right:388,bottom:172,left:264
# Found face 1 at top:48,right:388,bottom:172,left:264
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:48,right:424,bottom:228,left:248
# Found face 1 at top:72,right:420,bottom:224,left:268
# Found face 1 at top:72,right:420,bottom:224,left:268
# Found face 1 at top:68,right:444,bottom:248,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:40,right:436,bottom:188,left:288
# Found face 1 at top:24,right:436,bottom:172,left:288
# Found face 1 at top:40,right:436,bottom:188,left:288
# Found face 1 at top:48,right:416,bottom:172,left:292
# Found face 1 at top:48,right:416,bottom:172,left:292
# Found face 1 at top:32,right:404,bottom:156,left:280
# Found face 1 at top:32,right:404,bottom:156,left:280
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:32,right:388,bottom:156,left:264
# Found face 1 at top:48,right:388,bottom:172,left:264
# Found face 1 at top:48,right:388,bottom:172,left:264
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:40,right:404,bottom:188,left:252
# Found face 1 at top:48,right:424,bottom:228,left:248
# Found face 1 at top:48,right:424,bottom:228,left:248
# Found face 1 at top:68,right:424,bottom:248,left:248
# Found face 1 at top:68,right:424,bottom:248,left:248
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:60,right:440,bottom:276,left:224
# Found face 1 at top:60,right:440,bottom:276,left:224
# Found face 1 at top:60,right:440,bottom:276,left:224
# Found face 1 at top:60,right:440,bottom:276,left:224
# Found face 1 at top:60,right:464,bottom:276,left:248
# Found face 1 at top:60,right:464,bottom:276,left:248
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:60,right:488,bottom:276,left:272
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:60,right:512,bottom:276,left:296
# Found face 1 at top:60,right:512,bottom:276,left:296
# Found face 1 at top:60,right:512,bottom:276,left:296
# Found face 1 at top:60,right:512,bottom:276,left:296
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:68,right:484,bottom:248,left:304
# Found face 1 at top:68,right:484,bottom:248,left:304
# Found face 1 at top:68,right:484,bottom:248,left:304
# Found face 1 at top:68,right:484,bottom:248,left:304
# Found face 1 at top:60,right:512,bottom:276,left:296
# Found face 1 at top:60,right:536,bottom:276,left:320
# Found face 1 at top:60,right:536,bottom:276,left:320
# Found face 1 at top:88,right:544,bottom:268,left:364
# Found face 1 at top:88,right:544,bottom:268,left:364
# Found face 1 at top:84,right:584,bottom:300,left:368
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:564,bottom:288,left:384
# Found face 1 at top:108,right:524,bottom:288,left:344
# Found face 1 at top:108,right:524,bottom:288,left:344
# Found face 1 at top:84,right:560,bottom:300,left:344
# Found face 1 at top:88,right:564,bottom:268,left:384
# Found face 1 at top:68,right:564,bottom:248,left:384
# Found face 1 at top:68,right:584,bottom:248,left:404
# Found face 1 at top:68,right:584,bottom:248,left:404
# Found face 1 at top:48,right:624,bottom:228,left:444
# Found face 1 at top:24,right:640,bottom:172,left:520
# Found face 1 at top:12,right:640,bottom:188,left:464
# Found face 1 at top:12,right:640,bottom:188,left:464
# Found face 1 at top:32,right:584,bottom:208,left:404
# Found face 1 at top:32,right:564,bottom:208,left:384
# Found face 1 at top:48,right:504,bottom:228,left:324
# Found face 1 at top:48,right:504,bottom:228,left:324
# Found face 1 at top:48,right:464,bottom:228,left:284
# Found face 1 at top:72,right:436,bottom:224,left:288
# Found face 1 at top:68,right:444,bottom:248,left:264
# Found face 1 at top:68,right:404,bottom:248,left:228
# Found face 1 at top:68,right:404,bottom:248,left:228
# Found face 1 at top:68,right:404,bottom:248,left:228
# Found face 1 at top:88,right:404,bottom:268,left:228
# Found face 1 at top:88,right:404,bottom:268,left:228
# Found face 1 at top:88,right:404,bottom:268,left:228
# Found face 1 at top:88,right:424,bottom:268,left:248
# Found face 1 at top:88,right:424,bottom:268,left:248
# Found face 1 at top:88,right:424,bottom:268,left:248
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:444,bottom:268,left:264
# Found face 1 at top:88,right:464,bottom:268,left:284
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:108,right:512,bottom:324,left:296
# Found face 1 at top:128,right:484,bottom:308,left:304
# Found face 1 at top:108,right:488,bottom:324,left:272
# Found face 1 at top:128,right:464,bottom:308,left:284
# Found face 1 at top:128,right:464,bottom:308,left:284
# Found face 1 at top:128,right:464,bottom:308,left:284
# Found face 1 at top:128,right:464,bottom:308,left:284
# Found face 1 at top:128,right:444,bottom:308,left:264
# Found face 1 at top:108,right:464,bottom:324,left:248
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:84,right:464,bottom:300,left:248
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:108,right:464,bottom:288,left:284
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:108,right:484,bottom:288,left:304
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:84,right:488,bottom:300,left:272
# Found face 1 at top:88,right:484,bottom:268,left:304
# Found face 1 at top:88,right:484,bottom:268,left:304
